# %%
def add_student(records,name,marks):
    avg=sum(marks)/len(marks)
    records[name]={
        "marks":marks
        "average":avg
    }
# Out:
#   Cell In[6], line 5
#     "average":avg
#     ^
# SyntaxError: invalid syntax
